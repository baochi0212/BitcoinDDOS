# %%
# !git clone https://baochi0212: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@github.com/baochi0212/Crypto2022
# Out:
# Cloning into 'Crypto2022'...
# remote: Enumerating objects: 351, done.
# remote: Counting objects: 100% (64/64), done.
# remote: Compressing objects: 100% (40/40), done.
# remote: Total 351 (delta 33), reused 51 (delta 20), pack-reused 287
# Receiving objects: 100% (351/351), 39.69 MiB | 12.54 MiB/s, done.
# Resolving deltas: 100% (203/203), done.

# %% [markdown]
# # Data fetching

# %%
# %env dir=/content/Crypto2022
# Out:
# env: dir=/content/Crypto2022

# %%
# %cd /content/Crypto2022
# Out:
# /content/Crypto2022

# %%
# !git checkout feature/data/Chi #rename
# Out:
# error: Your local changes to the following files would be overwritten by checkout:
# 	Crypto2022.ipynb
# 	src/data/get_block.py
# Please commit your changes or stash them before you switch branches.
# error: The following untracked working tree files would be overwritten by checkout:
# 	.gitattributes
# 	data/.gitignore
# 	src/.gitignore
# 	src/data/extract_data.py
# Please move or remove them before you switch branches.
# Aborting

# %%
# !git pull
# Out:
# Already up to date.

# %%
# !apt install -q nginx
# !pip install -q fuckit
# Out:
#   Preparing metadata (setup.py) ... done
# ...

# %%
# #ONLY use for reset when bugging!
# !rm -rf data/raw/blockdata/attack/*.json data/raw/blockdata/normal/*.json data/*/blockdata/*/*.txt data/*/metadata/*.txt

# %%
#block
# !python src/data/get_block.py -> Can't make use of fuckit module -> loop Script:
#num_steps: error -> loop lai -> start: 0 ->  end: 1000 -> type: 2 folder: normal vs attack: 
# !bash src/*/spam_script.sh 0 0 1000 attack
# Out:
# Num steps: 0
# Step: 0, type: attack
# Limit: 0 -> 1000
# Fetched 997/1000
# ...

# %%
# %%bash
# git config --global user.email "chideptraiak29@gmail.com"
# git config --global user.name "baochi0212"
# git add .
# git commit -m "add data"
# git push

# %% [markdown]
# # Downloading and Extracting Data

# %% [markdown]
# ## Downloading json files from Kaggle

# %%
# Get data links in Kaggle and put here
data_links = [
    "https://www.kaggleusercontent.com/kf/116615268/eyJhbGciOiJkaXIiLCJlbmMiOiJBMTI4Q0JDLUhTMjU2In0..vHcOdnT8SKGEx4xCR_PH_A.Ci3grJ4BGP7b1AHh0EIKJQ7nCRYlh4URwkGbA3MGCYDyNI-xx_kjBZ3fkgOXXaRvCwSAfOTcJZ31hE5KuK7dnz9VkXvfwbKLZPwNSFBCJ04ypDDj0nbvHYLvDeHbYprPuGOnb67OXSwLQIt_89wXCuAIR0_xEigL7LL43SWUsBmy9odxJ_Qdl9mN2z8IpBRcFIh7B0VEc3wcuvkv54weVLqFWzM_914GD-xUZIb2Ww8Um36Lfm9HF8CL_G583-JQlKlJoQ28p12M1P9GDtfcc1Lp3ThfzmFZ-cD_MIYk00D_RMA33Fup-_tvVac1gzd_8_Lbcgv37I5fXQbGqr4Ab9JESBSIi3zxLxjI_ikWRKJAkXMsTYj1M5ieMEEXzlTSGHbpfYi4c7SOii4cXiSm08y0wrIdL0Fj57iG7WEgYas8ouXhB--fk3Abdjcy5WkvvnPCyBxM4Li6jDr39dXOBMWft2BNj0SU9fB8Bck2hjhgHWmC4XaHerryyMlHK_CzzAlfKSzPnvZN1V_iD-bsN5AiZHzuScpXTRkP1dvWM4slAUvJ2xADGI85yvS_miwaR6uKrAWOsE6G2eYZ_zNT8gB5X4GHcMZGypEb_IGfDCdzNSAqbpG93L3DQf930d8f2tgMeAjD7416G-oHjW1OGA.ANQc5CyRkV73ri94O6QT_w/Crypto2022/data/raw/blockdata/normal/normal_0_3500.json",
    "https://www.kaggleusercontent.com/kf/116615285/eyJhbGciOiJkaXIiLCJlbmMiOiJBMTI4Q0JDLUhTMjU2In0.._23Ma4KLg6BQZeyMzQYNpw.GQAwI8UR7B7nSEFyjbNSl_JLBlKdnuPUCTNr2paLDgfuNsVXDBjOozVRsE6GQtFYDSgjNALNaowsSgX5_i6MYVBLry5sn4WOXmVC1F0rNC8dIpqxBjWYlQcfa9BOoFupXTryfuOkOeIu1iXbQZyNoTTdni9iKq2d1t_8wYodhNIp_9maN7YUhzd1yZKFvhrtdozVtNBZlhgcwa5x8E5xJxYP_BrAFJ6DgfyrWQlZVzCyoVtVFFgRQH1shn0NsEMUQ9RctZSo3sdL98sRBUDCOsUvVN1iJkDjpi5P52RSoNAmKIoSGRNpjqLwJRpo8UQInlnhp0vzLVFdXeLa1ecYNf7ozkgkrhrveTxXlMqZ5b41Kd27z2fsHB-JuPF-Eo4rB9UsgWNh9_UaSrAL3z0Lq4OAjuS3HjN9JjaMMAZEpfVBN5i8E3qAETTei7N_Iq_uozGv54DHE4mOVLh3xEQ-HwBAYZ2skm-qIpfOE8tFzWncCdZS36tTgg_ff7ySUoYBto0OHwiXkcWdYeTqWKnzqK1gXISFgMr7H2ebjeV4atfSep2rlsrESMoaaZVtKLIBxMgQipPYnh5kPEPEj6GAbgKveUmJ9GvGBFF_ea6YmB8XHC5YdrOIzwJYd0_TC_aBdSw1qrfk9_L4RwTun3zpug.9xneV63RwmO7F_VITbeuFQ/Crypto2022/data/raw/blockdata/normal/normal_3500_7000.json"
]

# %%
import subprocess

# %%
# This cell will download all data links to data_dir folder
data_dir = "data/raw/blockdata/normal"
for link in data_links:
    subprocess.call(["wget", link, "-P", data_dir])
# Out:
# --2023-01-28 21:46:49--  https://www.kaggleusercontent.com/kf/116615268/eyJhbGciOiJkaXIiLCJlbmMiOiJBMTI4Q0JDLUhTMjU2In0..vHcOdnT8SKGEx4xCR_PH_A.Ci3grJ4BGP7b1AHh0EIKJQ7nCRYlh4URwkGbA3MGCYDyNI-xx_kjBZ3fkgOXXaRvCwSAfOTcJZ31hE5KuK7dnz9VkXvfwbKLZPwNSFBCJ04ypDDj0nbvHYLvDeHbYprPuGOnb67OXSwLQIt_89wXCuAIR0_xEigL7LL43SWUsBmy9odxJ_Qdl9mN2z8IpBRcFIh7B0VEc3wcuvkv54weVLqFWzM_914GD-xUZIb2Ww8Um36Lfm9HF8CL_G583-JQlKlJoQ28p12M1P9GDtfcc1Lp3ThfzmFZ-cD_MIYk00D_RMA33Fup-_tvVac1gzd_8_Lbcgv37I5fXQbGqr4Ab9JESBSIi3zxLxjI_ikWRKJAkXMsTYj1M5ieMEEXzlTSGHbpfYi4c7SOii4cXiSm08y0wrIdL0Fj57iG7WEgYas8ouXhB--fk3Abdjcy5WkvvnPCyBxM4Li6jDr39dXOBMWft2BNj0SU9fB8Bck2hjhgHWmC4XaHerryyMlHK_CzzAlfKSzPnvZN1V_iD-bsN5AiZHzuScpXTRkP1dvWM4slAUvJ2xADGI85yvS_miwaR6uKrAWOsE6G2eYZ_zNT8gB5X4GHcMZGypEb_IGfDCdzNSAqbpG93L3DQf930d8f2tgMeAjD7416G-oHjW1OGA.ANQc5CyRkV73ri94O6QT_w/Crypto2022/data/raw/blockdata/normal/normal_0_3500.json
# Resolving www.kaggleusercontent.com (www.kaggleusercontent.com)... 35.190.26.106
# ...

# %% [markdown]
# ## Extracting data

# %%
# Run this cell to extract data
# Change the --dir argument to specify folder containing all json files
# Change the --output_path argument to specify location of extracted data file
# !python3 src/data/extract_data.py --dir data/raw/blockdata/normal --output_path data/extracted_data/ddos_data_normal_0_70000.csv
# Out:
# 100%|█████████████████████████████████████████████| 2/2 [00:40<00:00, 20.44s/it]

# %%
# %%bash
# git config --global user.email "chideptraiak29@gmail.com"
# git config --global user.name "baochi0212"
# git add .
# git commit -m "add data"
# git push

# %% [markdown]
# #Modelling

# %%
import json

# %%
print(len(json.load(open("/content/Crypto2022/data/raw/blockdata/attack/attack_0_1000.json", 'r'))))
print(len(open("/content/Crypto2022/data/raw/blockdata/attack/record.txt", 'r').readlines()))
# Out:
# 991
# 1000
